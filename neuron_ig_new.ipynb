# %%
import os 
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

from LKN.utils import get_model
from LKN.ig import attribute
model_name = "meta-llama/Meta-Llama-3-8B-Instruct"
llm, tokenizer = get_model(model_name)
# Out:
# /home/bumjin/anaconda3/lib/python3.11/site-packages/transformers/utils/hub.py:110: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(
# `torch_dtype` is deprecated! Use `dtype` instead!
# /home/bumjin/anaconda3/lib/python3.11/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/home/bumjin/anaconda3/lib/python3.11/site-packages/torchvision/image.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# 2025-11-27 06:37:25.821265: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-27 06:37:25.836373: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-27 06:37:25.853021: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-27 06:37:25.858013: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-27 06:37:25.871818: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-27 06:37:26.808064: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
from LKN.utils import visualize_attribution
neurons = [(11, 10), (8, 10), (5, 10), (2, 10)]
input_text = "You are a bad kid. 아마도 그것은 사실이다. 나이에 따라서 다르게 행동하지 않도록 조심."
result = attribute(llm, tokenizer, model_name, input_text, neurons)
visualize_attribution(result, tokenizer, max_attr=0.004, num_tokens_per_line=20)
# Out:
# <div style="font-family: 'Nanum Gothic', 'Malgun Gothic', 'AppleGothic', 'Noto Sans CJK KR', sans-serif; line-height: 2.5; font-size: 14px;"><span style="background-color: rgb(255, 253, 251); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">&lt;|begin_of_text|&gt;</span><span style="background-color: rgb(255, 249, 242); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">You</span><span style="background-color: rgb(255, 249, 243); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> are</span><span style="background-color: rgb(255, 251, 246); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> a</span><span style="background-color: rgb(255, 245, 233); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> bad</span><span style="background-color: rgb(255, 241, 225); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> kid</span><span style="background-color: rgb(255, 253, 250); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">.</span><span style="background-color: rgb(255, 242, 228); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 아</span><span style="background-color: rgb(255, 236, 213); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">마</span><span style="background-color: rgb(255, 242, 226); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">도</span><span style="background-color: rgb(255, 236, 213); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 그것</span><span style="background-color: rgb(255, 247, 238); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">은</span><span style="background-color: rgb(255, 241, 225); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 사실</span><span style="background-color: rgb(255, 243, 229); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">이다</span><span style="background-color: rgb(255, 253, 252); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">.</span><span style="background-color: rgb(255, 236, 212); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 나이</span><span style="background-color: rgb(255, 245, 233); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">에</span><span style="background-color: rgb(255, 233, 208); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 따라</span><span style="background-color: rgb(255, 247, 238); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">서</span><span style="background-color: rgb(255, 241, 225); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; ...

# %%
import json 
data = json.load(open("data/sample.json")) 
concepts = list(data.keys())

# %%
input_post_text = " ".join([ data[concepts[0]]['pos'][i] for i in range(10)])
input_neg_text = " ".join([ data[concepts[0]]['neg'][i] for i in range(10)])

# %%
probe_positions = None

neurons = [(11, i) for i in range(5, 100)]
result = attribute(llm, tokenizer, model_name, input_post_text, neurons, probe_positions)
visualize_attribution(result, tokenizer,  num_tokens_per_line=20)

# neurons = [(7, i) for i in range(5, 100)] 
# neurons = [(7, 11000)] 
result = attribute(llm, tokenizer, model_name, input_post_text, neurons, probe_positions)
visualize_attribution(result, tokenizer,  num_tokens_per_line=20)
# Out:
# <div style="font-family: 'Nanum Gothic', 'Malgun Gothic', 'AppleGothic', 'Noto Sans CJK KR', sans-serif; line-height: 2.5; font-size: 14px;"><span style="background-color: rgb(255, 227, 193); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">&lt;|begin_of_text|&gt;</span><span style="background-color: rgb(255, 140, 0); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">젊은</span><span style="background-color: rgb(255, 142, 5); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 사람은</span><span style="background-color: rgb(255, 180, 89); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 대부분</span><span style="background-color: rgb(255, 152, 28); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 배우</span><span style="background-color: rgb(255, 178, 85); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">는</span><span style="background-color: rgb(255, 162, 49); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 속</span><span style="background-color: rgb(255, 184, 99); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">도가</span><span style="background-color: rgb(255, 198, 128); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 빠</span><span style="background-color: rgb(255, 216, 169); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">르</span><span style="background-color: rgb(255, 214, 166); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">다</span><span style="background-color: rgb(255, 232, 205); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">.</span><span style="background-color: rgb(255, 160, 44); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 나이</span><span style="background-color: rgb(255, 223, 185); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">가</span><span style="background-color: rgb(255, 209, 154); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 많은</span><span style="background-color: rgb(255, 204, 142); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 사람은</span><span style="background-color: rgb(255, 192, 115); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 변화</span><span style="background-color: rgb(255, 211, 158); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">에</span><span style="background-color: rgb(255, 207, 150); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 잘</span><span style="background-color: rgb(255, 220, 178); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: bl ...
# <div style="font-family: 'Nanum Gothic', 'Malgun Gothic', 'AppleGothic', 'Noto Sans CJK KR', sans-serif; line-height: 2.5; font-size: 14px;"><span style="background-color: rgb(255, 227, 193); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">&lt;|begin_of_text|&gt;</span><span style="background-color: rgb(255, 140, 0); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">젊은</span><span style="background-color: rgb(255, 142, 5); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 사람은</span><span style="background-color: rgb(255, 180, 89); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 대부분</span><span style="background-color: rgb(255, 152, 28); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 배우</span><span style="background-color: rgb(255, 178, 85); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">는</span><span style="background-color: rgb(255, 162, 49); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 속</span><span style="background-color: rgb(255, 184, 99); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">도가</span><span style="background-color: rgb(255, 198, 128); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 빠</span><span style="background-color: rgb(255, 216, 169); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">르</span><span style="background-color: rgb(255, 214, 166); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">다</span><span style="background-color: rgb(255, 232, 205); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">.</span><span style="background-color: rgb(255, 160, 44); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 나이</span><span style="background-color: rgb(255, 223, 185); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">가</span><span style="background-color: rgb(255, 209, 154); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 많은</span><span style="background-color: rgb(255, 204, 142); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 사람은</span><span style="background-color: rgb(255, 192, 115); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 변화</span><span style="background-color: rgb(255, 211, 158); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">에</span><span style="background-color: rgb(255, 207, 150); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 잘</span><span style="background-color: rgb(255, 220, 178); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: bl ...

# %%
neurons = [(27, 10101)] 
result = attribute(llm, tokenizer, model_name, input_post_text, neurons, probe_positions)
visualize_attribution(result, tokenizer,  num_tokens_per_line=20)
# Out:
# <div style="font-family: 'Nanum Gothic', 'Malgun Gothic', 'AppleGothic', 'Noto Sans CJK KR', sans-serif; line-height: 2.5; font-size: 14px;"><span style="background-color: rgb(255, 225, 189); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">&lt;|begin_of_text|&gt;</span><span style="background-color: rgb(255, 165, 56); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">젊은</span><span style="background-color: rgb(255, 179, 87); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 사람은</span><span style="background-color: rgb(255, 184, 98); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 대부분</span><span style="background-color: rgb(255, 140, 0); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 배우</span><span style="background-color: rgb(255, 213, 162); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">는</span><span style="background-color: rgb(255, 185, 100); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 속</span><span style="background-color: rgb(255, 217, 171); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">도가</span><span style="background-color: rgb(255, 217, 171); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 빠</span><span style="background-color: rgb(255, 222, 183); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">르</span><span style="background-color: rgb(255, 224, 188); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">다</span><span style="background-color: rgb(255, 242, 228); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">.</span><span style="background-color: rgb(255, 191, 115); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 나이</span><span style="background-color: rgb(255, 228, 196); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">가</span><span style="background-color: rgb(255, 206, 147); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 많은</span><span style="background-color: rgb(255, 225, 189); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 사람은</span><span style="background-color: rgb(255, 215, 168); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 변화</span><span style="background-color: rgb(255, 230, 200); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;">에</span><span style="background-color: rgb(255, 231, 203); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; color: black; white-space: nowrap;"> 잘</span><span style="background-color: rgb(255, 235, 211); padding: 5px 8px; margin: 2px; border: 1px solid #ccc; border-radius: 3px; display: inline-block; colo ...
